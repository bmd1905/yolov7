# %%
import time
from pathlib import Path
from icecream import ic
import cv2
import torch
import torch.backends.cudnn as cudnn
from numpy import random

from models.experimental import attempt_load
from utils.datasets import LoadStreams, LoadImages
from utils.general import check_img_size, check_requirements, check_imshow, non_max_suppression, apply_classifier, \
    scale_coords, xyxy2xywh, strip_optimizer, set_logging, increment_path
from utils.torch_utils import select_device, load_classifier, time_synchronized, TracedModel

# %% [markdown]
# ## Init YOLOv7

# %%
def plot_one_box(x, img, color=None, label=None, line_thickness=3):
    # Plots one bounding box on image img
    tl = line_thickness or round(0.002 * (img.shape[0] + img.shape[1]) / 2) + 1  # line/font thickness
    color = color or [random.randint(0, 255) for _ in range(3)]
    c1, c2 = (int(x[0]), int(x[1])), (int(x[2]), int(x[3]))
    cv2.rectangle(img, c1, c2, color, thickness=tl, lineType=cv2.LINE_AA)
    if label:
        tf = max(tl - 1, 1)  # font thickness
        t_size = cv2.getTextSize(label, 0, fontScale=tl / 3, thickness=tf)[0]
        c2 = c1[0] + t_size[0], c1[1] - t_size[1] - 3
        cv2.rectangle(img, c1, c2, color, -1, cv2.LINE_AA)  # filled
        cv2.putText(img, label, (c1[0], c1[1] - 2), 0, tl / 3, [225, 255, 255], thickness=tf, lineType=cv2.LINE_AA)

# %% [markdown]
# ## Init Unet

# %%
import argparse
import logging
import os
import pandas
import numpy as np
import torch
import torch.nn.functional as F
from PIL import Image
# %matplotlib widget
import matplotlib.pyplot as plt
from torchvision import transforms

from utils.data_loading import BasicDataset
from unet import UNet

def predict_img(net,
                full_img,
                device,
                scale_factor=1,
                out_threshold=0.5):
    #net.eval()
    img = torch.from_numpy(BasicDataset.preprocess(None, full_img, scale_factor, is_mask=False))
    img = img.unsqueeze(0)
    img = img.to(device=device, dtype=torch.float32)

    with torch.no_grad():
        output = net(img).cpu()
        output = F.interpolate(output, (full_img.size[1], full_img.size[0]), mode='bilinear')
        if net.n_classes > 1:
            mask = output.argmax(dim=1)
        else:
            mask = torch.sigmoid(output) > out_threshold

    return mask[0].long().squeeze().numpy()

def get_output_filenames(args):
    def _generate_name(fn):
        return f'{os.path.splitext(fn)[0]}_OUT.png'

    return args.output or list(map(_generate_name, args.input))

def mask_to_image(mask: np.ndarray, mask_values):
    if isinstance(mask_values[0], list):
        out = np.zeros((mask.shape[-2], mask.shape[-1], len(mask_values[0])), dtype=np.uint8)
    elif mask_values == [0, 1]:
        out = np.zeros((mask.shape[-2], mask.shape[-1]), dtype=bool)
    else:
        out = np.zeros((mask.shape[-2], mask.shape[-1]), dtype=np.uint8)

    if mask.ndim == 3:
        mask = np.argmax(mask, axis=0)

    for i, v in enumerate(mask_values):
        out[mask == i] = v

    return Image.fromarray(out)

def plot_img_and_mask(img, mask):
    classes = mask.max() + 1
    fig, ax = plt.subplots(1, classes + 1)
    ax[0].set_title('Input image')
    ax[0].imshow(img)
    for i in range(classes):
        ax[i + 1].set_title(f'Mask (class {i + 1})')
        ax[i + 1].imshow(mask == i)
    plt.xticks([]), plt.yticks([])
    plt.show()

def find_start_end_points(array):
    # Convert the input array to a NumPy array
    np_array = np.array(array)

    # Find the indices of the elements equal to 1
    end_indices = np.where(np_array == 1)
    start_indices = np.where(np_array[::-1, ::-1] == 1)

    # Calculate the actual indices of the starting and ending points
    end_point = (end_indices[0][0], end_indices[1][0])
    start_point = (np_array.shape[0] - start_indices[0][0] - 1, np_array.shape[1] - start_indices[1][0] - 1)

    # end_point = (79, 80)
    # start_point = (0, 65)

    return start_point, end_point

# %%
# filename = 'samples/10.png'

# def predict(filename):
#     img = Image.open(filename)

#     mask = predict_img(net=unet,
#                             full_img=img,
#                             scale_factor=1.0,
#                             out_threshold=0.5,
#                             device=device)
    
#     (pandas.DataFrame(mask).to_csv(f'{filename}.csv', header=None))
    
#     start_point, end_point = find_start_end_points(mask)
    
#     plot_img_and_mask(img, mask, start_point, end_point)


#     return mask, start_point, end_point

# %%
class Options:
    def __init__(self):
        self.weights_yolo = 'pretrain/yolov7-best.pt'
        self.weights_unet = 'pretrain/unet.pth'

        self.source = '../roboflow/car-traffic-light/valid/images/IMG_182_jpg.rf.22ac04dc9addb05fbda6d67dae5814e9.jpg'
        #self.source = '../video/video.mp4'
        
        self.img_size = 640
        self.conf_thres = 0.25
        self.iou_thres = 0.45
        self.device = ''
        self.view_img = False
        self.save_txt = False
        self.save_conf = False
        self.nosave = False
        self.classes = None
        self.agnostic_nms = False
        self.augment = False
        self.update = False
        self.project = 'runs/detect'
        self.name = 'exp'
        self.exist_ok = False
        self.no_trace = False

opt = Options()

# %%
unet = UNet(n_channels=3, n_classes=3, bilinear=False)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
unet.to(device=device)
state_dict = torch.load('pretrain/unet.pth', map_location=device)
mask_values = state_dict.pop('mask_values', [0, 1])
unet.load_state_dict(state_dict)
# Out:
# <All keys matched successfully>

# %%
# class YOLO_Unet(torch.nn.Module):
#     def __init__(self, opt):
#         super().__init__()

#         self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
#         self.save_img = not opt.nosave and not opt.source.endswith('.txt')  # save inference image
#         self.webcam = opt.source.isnumeric() or opt.source.endswith('.txt') or opt.source.lower().startswith(
#         ('rtsp://', 'rtmp://', 'http://', 'https://'))

#         # Unet
#         self.unet = UNet(n_channels=3, n_classes=3, bilinear=False).to(device=self.device)
#         state_dict = torch.load(opt.weights_unet, map_location=self.device)
#         self.unet.load_state_dict(state_dict)

#         # YOLOv7
#         self.yolo = attempt_load(opt.weights_yolo, map_location=self.device)  # load FP32 model
#         stride = int(self.yolo.stride.max())  # model stride
#         imgsz = check_img_size(imgsz, s=stride)  # check img_size

#         if opt.trace:
#             model = TracedModel(model, self.device, opt.img_size)

#         if opt.half:
#             model.half()  # to FP16

#         # Set Dataloader
#         self.vid_path, self.vid_writer = None, None
#         if opt.webcam:
#             self.view_img = check_imshow()
#             cudnn.benchmark = True  # set True to speed up constant image size inference
#             self.dataset = LoadStreams(opt.source, img_size=imgsz, stride=stride)
#         else:
#             self.dataset = LoadImages(opt.source, img_size=imgsz, stride=stride)


#         # Get names and colors
#         self.names = model.module.names if hasattr(model, 'module') else model.names
#         self.colors = [[random.randint(0, 255) for _ in range(3)] for _ in names]


#          # Run inference
#         try:
#             if self.device.type != 'cpu':
#                 self.yolo(torch.zeros(1, 3, imgsz, imgsz).to(self.device).type_as(next(model.parameters())))  # run once
#         except:
#             if self.device != 'cpu':
#                 self.yolo(torch.zeros(1, 3, imgsz, imgsz).to(self.device).type_as(next(model.parameters())))  # run once

#         self.old_img_w = self.old_img_h = imgsz
#         self.old_img_b = 1
        

#     def forward(self, path, img, im0s, vid_cap):
#         img = torch.from_numpy(img).to(self.device)
#         img = img.half() if self.half else img.float()  # uint8 to fp16/32
#         img /= 255.0  # 0 - 255 to 0.0 - 1.0
#         if img.ndimension() == 3:
#             img = img.unsqueeze(0)

#         # Warmup
#         try:
#             if self.device.type != 'cpu' and (old_img_b != img.shape[0] or old_img_h != img.shape[2] or old_img_w != img.shape[3]):
#                 old_img_b = img.shape[0]
#                 old_img_h = img.shape[2]
#                 old_img_w = img.shape[3]
#                 for i in range(3):
#                     self.yolo(img, augment=opt.augment)[0]
#         except:
#             if self.device != 'cpu' and (old_img_b != img.shape[0] or old_img_h != img.shape[2] or old_img_w != img.shape[3]):
#                 old_img_b = img.shape[0]
#                 old_img_h = img.shape[2]
#                 old_img_w = img.shape[3]
#                 for i in range(3):
#                     self.yolo(img, augment=opt.augment)[0]

#         # Inference
#         t1 = time_synchronized()
#         with torch.no_grad():   # Calculating gradients would cause a GPU memory leak
#             pred = self.yolo(img, augment=opt.augment)[0]
#         t2 = time_synchronized()

#         # Apply NMS
#         pred = non_max_suppression(pred, opt.conf_thres, opt.iou_thres, classes=opt.classes, agnostic=opt.agnostic_nms)
#         t3 = time_synchronized()

#         # Process detections
#         for i, det in enumerate(pred):  # detections per image
#             if self.webcam:  # batch_size >= 1
#                 p, s, im0, frame = path[i], '%g: ' % i, im0s[i].copy(), self.dataset.count
#             else:
#                 p, s, im0, frame = path, '', im0s, getattr(self.dataset, 'frame', 0)

#             p = Path(p)  # to Path
#             save_path = str(self.save_dir / p.name)  # img.jpg
#             txt_path = str(self.save_dir / 'labels' / p.stem) + ('' if self.dataset.mode == 'image' else f'_{frame}')  # img.txt
#             gn = torch.tensor(im0.shape)[[1, 0, 1, 0]]  # normalization gain whwh
#             if len(det):
#                 # Rescale boxes from img_size to im0 size
#                 det[:, :4] = scale_coords(img.shape[2:], det[:, :4], im0.shape).round()

#                 # Print results
#                 for c in det[:, -1].unique():
#                     n = (det[:, -1] == c).sum()  # detections per class
#                     s += f"{n} {self.names[int(c)]}{'s' * (n > 1)}, "  # add to string

#                 # Write results
#                 for *xyxy, conf, cls in reversed(det):
#                     if self.save_txt:  # Write to file
#                         xywh = (xyxy2xywh(torch.tensor(xyxy).view(1, 4)) / gn).view(-1).tolist()  # normalized xywh
#                         line = (cls, *xywh, conf) if opt.save_conf else (cls, *xywh)  # label format
#                         with open(txt_path + '.txt', 'a') as f:
#                             f.write(('%g ' * len(line)).rstrip() % line + '\n')

#                     if self.save_img or self.view_img:  # Add bbox to image
#                         label = f'{self.names[int(cls)]} {conf:.2f}'
#                         # Create bouding box and save in im0 variable
#                         plot_one_box(xyxy, im0, label=label, color=self.colors[int(cls)], line_thickness=1)

#             #im0 = im0.astype('uint8')

#             # Convert the numpy array into a PIL image
#             im0 = Image.fromarray(im0)

#             # Segmentation step
#             img_mask = predict_img(net=self.unet,
#                             full_img=im0,
#                             scale_factor=1.0,
#                             out_threshold=0.5,
#                             device=self.device)
            

#             im0 = np.array(im0)
#             img_mask = np.array(img_mask)

#             # Convert the mask image to binary
#             img_bin = img_mask

#             img_bin = img_bin.astype(np.uint8)
#             im0 = im0.astype(np.uint8)

#             # Extract the part of the RGB image that corresponds to the nonzero values of the binary mask
#             img_rgb = cv2.bitwise_and(im0, im0, mask=img_bin)

#             # Create an alpha channel from the binary mask
#             img_alpha = np.zeros_like(im0[:,:,0])
#             img_alpha[img_bin > 0] = 0

#             # Combine the RGB image and the alpha channel to get the final RGBA image
#             return np.dstack((img_rgb, img_alpha))

# %%
 # Load model
yolo = attempt_load(opt.weights_yolo, map_location=device)  # load FP32 model
stride = int(yolo.stride.max())  # model stride
imgsz = check_img_size(opt.img_size, s=stride)  # check img_size

if True:
    yolo = TracedModel(yolo, device, opt.img_size)
# Out:
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# /Users/bmd1905/miniforge3/envs/yolov7_env/lib/python3.10/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/TensorShape.cpp:3484.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!

# %%
def detect(save_img=False):
    source, weights_yolo, view_img, save_txt, imgsz, trace = opt.source, opt.weights_yolo, opt.view_img, opt.save_txt, opt.img_size, not opt.no_trace
    save_img = not opt.nosave and not source.endswith('.txt')  # save inference images
    webcam = source.isnumeric() or source.endswith('.txt') or source.lower().startswith(
        ('rtsp://', 'rtmp://', 'http://', 'https://'))

    # Directories
    save_dir = Path(increment_path(Path(opt.project) / opt.name, exist_ok=opt.exist_ok))  # increment run
    (save_dir / 'labels' if save_txt else save_dir).mkdir(parents=True, exist_ok=True)  # make dir

    # Initialize
    device = select_device(opt.device)
    half = device.type != 'cpu'  # half precision only supported on CUDA

    # device = 'mps'
    # half = True


    # Set Dataloader
    vid_path, vid_writer = None, None
    if webcam:
        view_img = check_imshow()
        cudnn.benchmark = True  # set True to speed up constant image size inference
        dataset = LoadStreams(source, img_size=imgsz, stride=stride)
    else:
        dataset = LoadImages(source, img_size=imgsz, stride=stride)

    # Get names and colors
    names = yolo.module.names if hasattr(yolo, 'module') else yolo.names
    colors = [[random.randint(0, 255) for _ in range(3)] for _ in names]

    # Run inference
    if device.type != 'cpu':
            yolo(torch.zeros(1, 3, imgsz, imgsz).to(device).type_as(next(yolo.parameters())))  # run once

    old_img_w = old_img_h = imgsz
    old_img_b = 1

    t0 = time.time()
    for path, img, im0s, vid_cap in dataset:
        # print(img.shape)
        # if img.ndim == 2:
        #     unet_img = img[np.newaxis, ...]
        # else:
        #     unet_img = img.transpose((2, 0, 1))

        # unet_img = torch.from_numpy(BasicDataset.preprocess_combine(None, unet_img, 1.0, is_mask=False))
        # print(unet_img.shape)
        # print(im0s.shape)
        np_img0s = im0s
        print(np_img0s.shape)
        img = torch.from_numpy(img).to(device)
        img = img.half() if half else img.float()  # uint8 to fp16/32
        img /= 255.0  # 0 - 255 to 0.0 - 1.0
        if img.ndimension() == 3:
            img = img.unsqueeze(0)
        # print(img.shape)

       
        

        # yolo_input = yolo_preprocessing_image(img, device)
        # unet_input = unet_preprocessing_image(img, device)
        # print(f"{yolo_input.shape}, unet {unet_input.shape}")

        # Warmup
        if device.type != 'cpu' and (old_img_b != img.shape[0] or old_img_h != img.shape[2] or old_img_w != img.shape[3]):
                old_img_b = img.shape[0]
                old_img_h = img.shape[2]
                old_img_w = img.shape[3]
                for i in range(3):
                    yolo(img, augment=opt.augment)[0]

        # Inference
        t1 = time_synchronized()
        with torch.no_grad():   # Calculating gradients would cause a GPU memory leak
            # YOLO
            yolo_output = yolo(img, augment=opt.augment)[0]

            # Unet
            img_mask = unet(img).cpu()
            img_mask = F.interpolate(img_mask, (np_img0s.shape[0], np_img0s.shape[1]), mode='bilinear')
            if unet.n_classes > 1:
                img_mask = img_mask.argmax(dim=1)
            else:
                img_mask = torch.sigmoid(img_mask) > 0.5
            

        # print("Before handle", img_mask.shape)
        img_mask = img_mask[0].long().squeeze().numpy()
        # img_mask = np.array(img_mask)
        # print("With no grad mask shape", img_mask.shape)
        img_mask[:150,:] = 0


        t2 = time_synchronized()

        # Apply NMS
        yolo_output = non_max_suppression(yolo_output, opt.conf_thres, opt.iou_thres, classes=opt.classes, agnostic=opt.agnostic_nms)
        t3 = time_synchronized()

        # Process detections
        for i, det in enumerate(yolo_output):  # detections per image
            if webcam:  # batch_size >= 1
                p, s, im0, frame = path[i], '%g: ' % i, im0s[i].copy(), dataset.count
            else:
                p, s, im0, frame = path, '', im0s, getattr(dataset, 'frame', 0)

            p = Path(p)  # to Path
            save_path = str(save_dir / p.name)  # img.jpg
            txt_path = str(save_dir / 'labels' / p.stem) + ('' if dataset.mode == 'image' else f'_{frame}')  # img.txt
            gn = torch.tensor(im0.shape)[[1, 0, 1, 0]]  # normalization gain whwh
            if len(det):
                # Rescale boxes from img_size to im0 size
                det[:, :4] = scale_coords(img.shape[2:], det[:, :4], im0.shape).round()

                # Print results
                for c in det[:, -1].unique():
                    n = (det[:, -1] == c).sum()  # detections per class
                    s += f"{n} {names[int(c)]}{'s' * (n > 1)}, "  # add to string

                # Write results
                for *xyxy, conf, cls in reversed(det):
                    if save_txt:  # Write to file
                        xywh = (xyxy2xywh(torch.tensor(xyxy).view(1, 4)) / gn).view(-1).tolist()  # normalized xywh
                        line = (cls, *xywh, conf) if opt.save_conf else (cls, *xywh)  # label format
                        with open(txt_path + '.txt', 'a') as f:
                            f.write(('%g ' * len(line)).rstrip() % line + '\n')

                    if save_img or view_img:  # Add bbox to image
                        label = f'{names[int(cls)]} {conf:.2f}'
                        # Create bouding box and save in im0 variable
                        plot_one_box(xyxy, im0, label=label, color=colors[int(cls)], line_thickness=1)

            # im0 = im0.astype('uint8')

            # Convert the numpy array into a PIL image
            # im0 = Image.fromarray(im0)

            # Segmentation step
            # img_mask = predict_img(net=unet,
            #                 full_img=im0,
            #                 scale_factor=1.0,
            #                 out_threshold=0.5,
            #                 device=device)
            # print("mask shape", img_mask.shape)
            # print(im0.shape)
            

            # im0 = np.array(im0)
            # img_mask = np.array(img_mask)
            # print("im0 shape:", im0.shape, type(im0))
            #return im0, img_mask

            # Create a 3-channel binary mask from the 2D binary mask
            img_bin = np.zeros((img_mask.shape[0], img_mask.shape[1], 3), dtype=np.uint8)
            img_bin[img_mask == 1] = [255, 255, 255]

            # Create alpha image
            img_alpha = cv2.addWeighted(img_bin, 1, im0, 1, 1)
            img_rgba = cv2.cvtColor(img_alpha, cv2.COLOR_BGR2RGBA)  
            



            # im0 = cv2.cvtColor(im0, cv2.COLOR_BGR2RGBA)
            # plot_img_and_mask(im0, img_mask)

            # plt.imshow(im0)
            # plt.imshow(img_rgba)
            # plt.show()



            # Stream results
            if view_img:
                cv2.imshow(im0)
                cv2.waitKey(1)  # 1 millisecond

            # Save results (image with detections)
            if save_img:
                if dataset.mode == 'image':
                    cv2.imwrite(save_path, img_rgba)
                    print(f" The image with the result is saved in: {save_path}")
                else:  # 'video' or 'stream'
                    if vid_path != save_path:  # new video
                        vid_path = save_path
                        if isinstance(vid_writer, cv2.VideoWriter):
                            vid_writer.release()  # release previous video writer
                        if vid_cap:  # video
                            fps = vid_cap.get(cv2.CAP_PROP_FPS)
                            w = int(vid_cap.get(cv2.CAP_PROP_FRAME_WIDTH))
                            h = int(vid_cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
                        else:  # stream
                            fps, w, h = 30, img_rgba.shape[1], img_rgba.shape[0]
                            save_path += '.mp4'
                        vid_writer = cv2.VideoWriter(save_path, cv2.VideoWriter_fourcc(*'mp4v'), fps, (w, h))
                    vid_writer.write(img_rgba)


            # Print time (inference + NMS)
            print(f'{s}Done. ({(1E3 * (t2 - t1)):.1f}ms) Inference, ({(1E3 * (t3 - t2)):.1f}ms) NMS')

# %%
# opt.source = '../train_data/train/images/img_126.jpg'
opt.source = '../video/source.mp4'
img_rgba = detect()
# Out:
# video 1/1 (1/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2622.7ms) Inference, (0.3ms) NMS
# video 1/1 (2/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2036.6ms) Inference, (0.4ms) NMS
# video 1/1 (3/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2012.4ms) Inference, (0.3ms) NMS
# video 1/1 (4/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2120.9ms) Inference, (0.8ms) NMS
# video 1/1 (5/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2158.5ms) Inference, (0.6ms) NMS
# video 1/1 (6/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2078.4ms) Inference, (0.5ms) NMS
# video 1/1 (7/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2096.9ms) Inference, (0.4ms) NMS
# video 1/1 (8/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2046.9ms) Inference, (0.4ms) NMS
# video 1/1 (9/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2141.7ms) Inference, (0.7ms) NMS
# video 1/1 (10/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1965.1ms) Inference, (0.4ms) NMS
# video 1/1 (11/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2187.7ms) Inference, (0.3ms) NMS
# video 1/1 (12/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2043.6ms) Inference, (0.3ms) NMS
# video 1/1 (13/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1965.1ms) Inference, (0.1ms) NMS
# video 1/1 (14/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1594.6ms) Inference, (0.3ms) NMS
# video 1/1 (15/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1631.9ms) Inference, (0.1ms) NMS
# video 1/1 (16/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1685.8ms) Inference, (0.2ms) NMS
# video 1/1 (17/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1702.5ms) Inference, (0.2ms) NMS
# video 1/1 (18/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2407.5ms) Inference, (0.2ms) NMS
# video 1/1 (19/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1839.1ms) Inference, (0.4ms) NMS
# video 1/1 (20/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2182.9ms) Inference, (0.2ms) NMS
# video 1/1 (21/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2725.9ms) Inference, (0.9ms) NMS
# video 1/1 (22/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2408.1ms) Inference, (0.1ms) NMS
# video 1/1 (23/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2490.1ms) Inference, (0.6ms) NMS
# video 1/1 (24/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2785.1ms) Inference, (0.3ms) NMS
# video 1/1 (25/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1867.4ms) Inference, (0.3ms) NMS
# video 1/1 (26/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1826.1ms) Inference, (0.2ms) NMS
# video 1/1 (27/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1672.5ms) Inference, (0.3ms) NMS
# video 1/1 (28/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1734.3ms) Inference, (0.1ms) NMS
# video 1/1 (29/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1790.4ms) Inference, (0.2ms) NMS
# video 1/1 (30/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1695.7ms) Inference, (0.7ms) NMS
# video 1/1 (31/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1786.8ms) Inference, (0.1ms) NMS
# video 1/1 (32/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1761.4ms) Inference, (0.4ms) NMS
# video 1/1 (33/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1631.1ms) Inference, (0.4ms) NMS
# video 1/1 (34/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1748.3ms) Inference, (0.1ms) NMS
# video 1/1 (35/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1653.5ms) Inference, (0.5ms) NMS
# video 1/1 (36/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1797.0ms) Inference, (0.1ms) NMS
# video 1/1 (37/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1758.7ms) Inference, (0.1ms) NMS
# video 1/1 (38/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1889.5ms) Inference, (0.1ms) NMS
# video 1/1 (39/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1768.6ms) Inference, (0.7ms) NMS
# video 1/1 (40/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1739.4ms) Inference, (0.6ms) NMS
# video 1/1 (41/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1718.1ms) Inference, (0.5ms) NMS
# video 1/1 (42/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1676.8ms) Inference, (0.1ms) NMS
# video 1/1 (43/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1797.6ms) Inference, (0.1ms) NMS
# video 1/1 (44/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1691.7ms) Inference, (0.2ms) NMS
# video 1/1 (45/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1790.3ms) Inference, (0.4ms) NMS
# video 1/1 (46/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1803.3ms) Inference, (0.4ms) NMS
# video 1/1 (47/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1810.6ms) Inference, (0.1ms) NMS
# video 1/1 (48/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1798.2ms) Inference, (0.3ms) NMS
# video 1/1 (49/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1885.3ms) Inference, (0.3ms) NMS
# video 1/1 (50/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1738.8ms) Inference, (0.6ms) NMS
# video 1/1 (51/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1770.2ms) Inference, (0.2ms) NMS
# video 1/1 (52/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1799.1ms) Inference, (0.3ms) NMS
# video 1/1 (53/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1766.9ms) Inference, (0.1ms) NMS
# video 1/1 (54/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1810.2ms) Inference, (0.1ms) NMS
# video 1/1 (55/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1718.8ms) Inference, (0.3ms) NMS
# video 1/1 (56/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1826.6ms) Inference, (0.2ms) NMS
# video 1/1 (57/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1786.3ms) Inference, (0.2ms) NMS
# video 1/1 (58/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1825.0ms) Inference, (0.1ms) NMS
# video 1/1 (59/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1864.4ms) Inference, (0.3ms) NMS
# video 1/1 (60/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1749.6ms) Inference, (0.1ms) NMS
# video 1/1 (61/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1808.8ms) Inference, (0.3ms) NMS
# video 1/1 (62/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1791.0ms) Inference, (0.1ms) NMS
# video 1/1 (63/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1755.4ms) Inference, (0.3ms) NMS
# video 1/1 (64/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1729.4ms) Inference, (0.3ms) NMS
# video 1/1 (65/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1642.7ms) Inference, (0.6ms) NMS
# video 1/1 (66/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1742.5ms) Inference, (0.4ms) NMS
# video 1/1 (67/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1724.0ms) Inference, (0.2ms) NMS
# video 1/1 (68/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1883.5ms) Inference, (0.2ms) NMS
# video 1/1 (69/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1794.5ms) Inference, (0.4ms) NMS
# video 1/1 (70/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1763.4ms) Inference, (0.2ms) NMS
# video 1/1 (71/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1759.8ms) Inference, (0.5ms) NMS
# video 1/1 (72/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1779.2ms) Inference, (0.3ms) NMS
# video 1/1 (73/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1728.9ms) Inference, (0.6ms) NMS
# video 1/1 (74/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1704.4ms) Inference, (0.3ms) NMS
# video 1/1 (75/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1780.8ms) Inference, (1.0ms) NMS
# video 1/1 (76/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1731.3ms) Inference, (0.1ms) NMS
# video 1/1 (77/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1770.6ms) Inference, (0.4ms) NMS
# video 1/1 (78/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1745.8ms) Inference, (0.6ms) NMS
# video 1/1 (79/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1679.1ms) Inference, (0.4ms) NMS
# video 1/1 (80/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1793.1ms) Inference, (0.6ms) NMS
# video 1/1 (81/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1728.2ms) Inference, (0.2ms) NMS
# video 1/1 (82/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1767.1ms) Inference, (0.4ms) NMS
# video 1/1 (83/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1728.4ms) Inference, (0.1ms) NMS
# video 1/1 (84/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1760.2ms) Inference, (0.1ms) NMS
# video 1/1 (85/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1852.6ms) Inference, (0.2ms) NMS
# video 1/1 (86/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1739.3ms) Inference, (0.1ms) NMS
# video 1/1 (87/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1758.0ms) Inference, (0.1ms) NMS
# video 1/1 (88/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1752.2ms) Inference, (0.4ms) NMS
# video 1/1 (89/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1700.5ms) Inference, (0.2ms) NMS
# video 1/1 (90/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1767.2ms) Inference, (0.3ms) NMS
# video 1/1 (91/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1852.3ms) Inference, (0.5ms) NMS
# video 1/1 (92/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1761.6ms) Inference, (0.4ms) NMS
# video 1/1 (93/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1882.1ms) Inference, (0.3ms) NMS
# video 1/1 (94/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1919.6ms) Inference, (0.3ms) NMS
# video 1/1 (95/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1952.6ms) Inference, (0.5ms) NMS
# video 1/1 (96/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1724.8ms) Inference, (0.1ms) NMS
# video 1/1 (97/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1678.7ms) Inference, (0.1ms) NMS
# video 1/1 (98/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1677.1ms) Inference, (0.1ms) NMS
# video 1/1 (99/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1665.6ms) Inference, (0.5ms) NMS
# video 1/1 (100/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1613.9ms) Inference, (0.2ms) NMS
# video 1/1 (101/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1709.5ms) Inference, (0.3ms) NMS
# video 1/1 (102/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1893.2ms) Inference, (0.3ms) NMS
# video 1/1 (103/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1875.3ms) Inference, (0.1ms) NMS
# video 1/1 (104/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1952.1ms) Inference, (0.2ms) NMS
# video 1/1 (105/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1635.5ms) Inference, (0.5ms) NMS
# video 1/1 (106/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1657.1ms) Inference, (0.8ms) NMS
# video 1/1 (107/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1712.0ms) Inference, (0.1ms) NMS
# video 1/1 (108/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1696.2ms) Inference, (0.5ms) NMS
# video 1/1 (109/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1696.5ms) Inference, (0.6ms) NMS
# video 1/1 (110/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1775.5ms) Inference, (0.1ms) NMS
# video 1/1 (111/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1682.9ms) Inference, (0.2ms) NMS
# video 1/1 (112/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1814.9ms) Inference, (0.2ms) NMS
# video 1/1 (113/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2124.2ms) Inference, (0.3ms) NMS
# video 1/1 (114/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1993.3ms) Inference, (0.5ms) NMS
# video 1/1 (115/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1708.4ms) Inference, (0.1ms) NMS
# video 1/1 (116/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1701.6ms) Inference, (0.2ms) NMS
# video 1/1 (117/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1677.6ms) Inference, (0.4ms) NMS
# video 1/1 (118/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1737.4ms) Inference, (0.2ms) NMS
# video 1/1 (119/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1742.5ms) Inference, (0.3ms) NMS
# video 1/1 (120/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1791.3ms) Inference, (0.4ms) NMS
# video 1/1 (121/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1730.7ms) Inference, (0.7ms) NMS
# video 1/1 (122/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1783.3ms) Inference, (0.1ms) NMS
# video 1/1 (123/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1749.9ms) Inference, (0.5ms) NMS
# video 1/1 (124/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1806.1ms) Inference, (0.2ms) NMS
# video 1/1 (125/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1762.9ms) Inference, (0.5ms) NMS
# video 1/1 (126/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1744.0ms) Inference, (0.5ms) NMS
# video 1/1 (127/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1872.7ms) Inference, (0.3ms) NMS
# video 1/1 (128/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1770.2ms) Inference, (0.5ms) NMS
# video 1/1 (129/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1724.4ms) Inference, (0.2ms) NMS
# video 1/1 (130/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1759.2ms) Inference, (0.4ms) NMS
# video 1/1 (131/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1633.7ms) Inference, (0.1ms) NMS
# video 1/1 (132/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1712.1ms) Inference, (0.1ms) NMS
# video 1/1 (133/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1760.2ms) Inference, (0.1ms) NMS
# video 1/1 (134/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1722.1ms) Inference, (0.7ms) NMS
# video 1/1 (135/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1841.0ms) Inference, (0.4ms) NMS
# video 1/1 (136/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1792.5ms) Inference, (0.6ms) NMS
# video 1/1 (137/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1722.5ms) Inference, (0.4ms) NMS
# video 1/1 (138/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1717.6ms) Inference, (0.4ms) NMS
# video 1/1 (139/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1808.3ms) Inference, (0.5ms) NMS
# video 1/1 (140/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1705.2ms) Inference, (0.1ms) NMS
# video 1/1 (141/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1673.7ms) Inference, (0.2ms) NMS
# video 1/1 (142/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1730.9ms) Inference, (0.1ms) NMS
# video 1/1 (143/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1912.3ms) Inference, (0.2ms) NMS
# video 1/1 (144/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1891.0ms) Inference, (0.4ms) NMS
# video 1/1 (145/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2066.2ms) Inference, (0.2ms) NMS
# video 1/1 (146/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1997.9ms) Inference, (0.1ms) NMS
# video 1/1 (147/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1661.6ms) Inference, (0.1ms) NMS
# video 1/1 (148/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1731.7ms) Inference, (0.3ms) NMS
# video 1/1 (149/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1722.5ms) Inference, (0.3ms) NMS
# video 1/1 (150/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1672.5ms) Inference, (0.2ms) NMS
# video 1/1 (151/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1816.7ms) Inference, (0.2ms) NMS
# video 1/1 (152/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1917.8ms) Inference, (0.2ms) NMS
# video 1/1 (153/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2066.7ms) Inference, (0.3ms) NMS
# video 1/1 (154/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2008.0ms) Inference, (0.4ms) NMS
# video 1/1 (155/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1647.0ms) Inference, (0.1ms) NMS
# video 1/1 (156/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1764.5ms) Inference, (0.3ms) NMS
# video 1/1 (157/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1783.7ms) Inference, (0.2ms) NMS
# video 1/1 (158/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1770.1ms) Inference, (0.4ms) NMS
# video 1/1 (159/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1771.2ms) Inference, (0.2ms) NMS
# video 1/1 (160/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1750.0ms) Inference, (0.6ms) NMS
# video 1/1 (161/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1807.3ms) Inference, (0.1ms) NMS
# video 1/1 (162/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1673.7ms) Inference, (0.4ms) NMS
# video 1/1 (163/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2078.2ms) Inference, (0.4ms) NMS
# video 1/1 (164/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1804.3ms) Inference, (0.3ms) NMS
# video 1/1 (165/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2907.0ms) Inference, (0.8ms) NMS
# video 1/1 (166/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2436.0ms) Inference, (0.4ms) NMS
# video 1/1 (167/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2328.0ms) Inference, (0.5ms) NMS
# video 1/1 (168/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2536.8ms) Inference, (0.3ms) NMS
# video 1/1 (169/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2315.6ms) Inference, (0.1ms) NMS
# video 1/1 (170/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2373.2ms) Inference, (0.9ms) NMS
# video 1/1 (171/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2117.4ms) Inference, (0.2ms) NMS
# video 1/1 (172/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2175.9ms) Inference, (0.3ms) NMS
# video 1/1 (173/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2265.2ms) Inference, (0.5ms) NMS
# video 1/1 (174/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1935.1ms) Inference, (0.4ms) NMS
# video 1/1 (175/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2165.5ms) Inference, (0.2ms) NMS
# video 1/1 (176/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2061.7ms) Inference, (0.4ms) NMS
# video 1/1 (177/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2057.3ms) Inference, (1.9ms) NMS
# video 1/1 (178/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2103.3ms) Inference, (4.3ms) NMS
# video 1/1 (179/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2035.8ms) Inference, (0.3ms) NMS
# video 1/1 (180/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2035.5ms) Inference, (0.6ms) NMS
# video 1/1 (181/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2080.9ms) Inference, (0.4ms) NMS
# video 1/1 (182/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2844.2ms) Inference, (0.6ms) NMS
# video 1/1 (183/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2036.0ms) Inference, (0.2ms) NMS
# video 1/1 (184/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2160.0ms) Inference, (0.3ms) NMS
# video 1/1 (185/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2003.9ms) Inference, (0.8ms) NMS
# video 1/1 (186/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2125.5ms) Inference, (0.2ms) NMS
# video 1/1 (187/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2107.7ms) Inference, (0.4ms) NMS
# video 1/1 (188/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2684.0ms) Inference, (0.2ms) NMS
# video 1/1 (189/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2027.6ms) Inference, (1.0ms) NMS
# video 1/1 (190/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (3284.4ms) Inference, (0.5ms) NMS
# video 1/1 (191/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (3496.2ms) Inference, (0.5ms) NMS
# video 1/1 (192/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2110.5ms) Inference, (0.2ms) NMS
# video 1/1 (193/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2315.2ms) Inference, (0.6ms) NMS
# video 1/1 (194/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2164.9ms) Inference, (0.2ms) NMS
# video 1/1 (195/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1762.4ms) Inference, (0.2ms) NMS
# video 1/1 (196/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1666.1ms) Inference, (0.1ms) NMS
# video 1/1 (197/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1930.7ms) Inference, (0.3ms) NMS
# video 1/1 (198/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2609.0ms) Inference, (0.3ms) NMS
# video 1/1 (199/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2338.3ms) Inference, (0.4ms) NMS
# video 1/1 (200/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1970.7ms) Inference, (0.2ms) NMS
# video 1/1 (201/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2170.1ms) Inference, (0.2ms) NMS
# video 1/1 (202/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2055.4ms) Inference, (0.2ms) NMS
# video 1/1 (203/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1723.3ms) Inference, (0.1ms) NMS
# video 1/1 (204/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1870.5ms) Inference, (0.1ms) NMS
# video 1/1 (205/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1722.7ms) Inference, (0.4ms) NMS
# video 1/1 (206/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1681.0ms) Inference, (0.1ms) NMS
# video 1/1 (207/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1812.7ms) Inference, (0.4ms) NMS
# video 1/1 (208/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1859.9ms) Inference, (0.5ms) NMS
# video 1/1 (209/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1802.8ms) Inference, (0.1ms) NMS
# video 1/1 (210/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1863.2ms) Inference, (0.2ms) NMS
# video 1/1 (211/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1739.0ms) Inference, (0.1ms) NMS
# video 1/1 (212/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1792.7ms) Inference, (0.3ms) NMS
# video 1/1 (213/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1708.6ms) Inference, (0.4ms) NMS
# video 1/1 (214/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1746.1ms) Inference, (0.1ms) NMS
# video 1/1 (215/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1845.9ms) Inference, (0.1ms) NMS
# video 1/1 (216/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1666.1ms) Inference, (0.2ms) NMS
# video 1/1 (217/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1756.7ms) Inference, (0.4ms) NMS
# video 1/1 (218/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1807.1ms) Inference, (0.5ms) NMS
# video 1/1 (219/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1724.8ms) Inference, (0.1ms) NMS
# video 1/1 (220/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1756.4ms) Inference, (0.3ms) NMS
# video 1/1 (221/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1845.4ms) Inference, (0.3ms) NMS
# video 1/1 (222/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1787.3ms) Inference, (0.1ms) NMS
# video 1/1 (223/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1751.2ms) Inference, (0.6ms) NMS
# video 1/1 (224/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1783.4ms) Inference, (0.2ms) NMS
# video 1/1 (225/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1755.3ms) Inference, (0.4ms) NMS
# video 1/1 (226/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1830.0ms) Inference, (0.1ms) NMS
# video 1/1 (227/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1727.8ms) Inference, (0.2ms) NMS
# video 1/1 (228/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1754.0ms) Inference, (0.5ms) NMS
# video 1/1 (229/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1712.0ms) Inference, (0.1ms) NMS
# video 1/1 (230/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1696.0ms) Inference, (0.4ms) NMS
# video 1/1 (231/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1844.2ms) Inference, (0.2ms) NMS
# video 1/1 (232/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1636.2ms) Inference, (0.1ms) NMS
# video 1/1 (233/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1810.6ms) Inference, (0.2ms) NMS
# video 1/1 (234/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1707.1ms) Inference, (0.1ms) NMS
# video 1/1 (235/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2245.7ms) Inference, (9.1ms) NMS
# video 1/1 (236/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2232.3ms) Inference, (0.4ms) NMS
# video 1/1 (237/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2087.1ms) Inference, (0.4ms) NMS
# video 1/1 (238/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2465.5ms) Inference, (0.3ms) NMS
# video 1/1 (239/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2035.6ms) Inference, (0.4ms) NMS
# video 1/1 (240/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1722.3ms) Inference, (0.1ms) NMS
# video 1/1 (241/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2846.2ms) Inference, (0.6ms) NMS
# video 1/1 (242/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2132.5ms) Inference, (0.6ms) NMS
# video 1/1 (243/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1797.2ms) Inference, (0.2ms) NMS
# video 1/1 (244/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2353.4ms) Inference, (0.3ms) NMS
# video 1/1 (245/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2063.8ms) Inference, (0.4ms) NMS
# video 1/1 (246/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1786.9ms) Inference, (0.2ms) NMS
# video 1/1 (247/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1715.6ms) Inference, (0.3ms) NMS
# video 1/1 (248/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1920.2ms) Inference, (0.4ms) NMS
# video 1/1 (249/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1732.5ms) Inference, (0.2ms) NMS
# video 1/1 (250/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1699.4ms) Inference, (0.7ms) NMS
# video 1/1 (251/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2000.7ms) Inference, (0.5ms) NMS
# video 1/1 (252/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1801.5ms) Inference, (0.2ms) NMS
# video 1/1 (253/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1822.2ms) Inference, (0.2ms) NMS
# video 1/1 (254/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1946.5ms) Inference, (0.6ms) NMS
# video 1/1 (255/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2191.7ms) Inference, (0.3ms) NMS
# video 1/1 (256/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1912.3ms) Inference, (0.2ms) NMS
# video 1/1 (257/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1753.9ms) Inference, (0.5ms) NMS
# video 1/1 (258/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1748.0ms) Inference, (0.2ms) NMS
# video 1/1 (259/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1651.0ms) Inference, (0.1ms) NMS
# video 1/1 (260/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1845.8ms) Inference, (0.1ms) NMS
# video 1/1 (261/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1690.2ms) Inference, (0.1ms) NMS
# video 1/1 (262/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1809.7ms) Inference, (0.1ms) NMS
# video 1/1 (263/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1724.8ms) Inference, (0.1ms) NMS
# video 1/1 (264/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1757.4ms) Inference, (0.1ms) NMS
# video 1/1 (265/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1774.1ms) Inference, (0.5ms) NMS
# video 1/1 (266/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1840.7ms) Inference, (0.4ms) NMS
# video 1/1 (267/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1886.8ms) Inference, (0.2ms) NMS
# video 1/1 (268/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1811.7ms) Inference, (0.1ms) NMS
# video 1/1 (269/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1784.4ms) Inference, (0.1ms) NMS
# video 1/1 (270/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1762.9ms) Inference, (0.3ms) NMS
# video 1/1 (271/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1834.5ms) Inference, (0.2ms) NMS
# video 1/1 (272/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1801.6ms) Inference, (0.5ms) NMS
# video 1/1 (273/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1660.7ms) Inference, (0.1ms) NMS
# video 1/1 (274/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1967.6ms) Inference, (0.1ms) NMS
# video 1/1 (275/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1779.8ms) Inference, (0.6ms) NMS
# video 1/1 (276/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1718.7ms) Inference, (0.1ms) NMS
# video 1/1 (277/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1909.4ms) Inference, (0.4ms) NMS
# video 1/1 (278/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1743.8ms) Inference, (0.2ms) NMS
# video 1/1 (279/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1905.3ms) Inference, (0.5ms) NMS
# video 1/1 (280/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1977.8ms) Inference, (0.3ms) NMS
# video 1/1 (281/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1791.0ms) Inference, (0.1ms) NMS
# video 1/1 (282/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1704.7ms) Inference, (0.2ms) NMS
# video 1/1 (283/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1891.2ms) Inference, (0.3ms) NMS
# video 1/1 (284/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1738.3ms) Inference, (0.6ms) NMS
# video 1/1 (285/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1714.3ms) Inference, (0.2ms) NMS
# video 1/1 (286/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2335.6ms) Inference, (0.6ms) NMS
# video 1/1 (287/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2473.2ms) Inference, (0.4ms) NMS
# video 1/1 (288/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2169.0ms) Inference, (0.2ms) NMS
# video 1/1 (289/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1855.3ms) Inference, (0.3ms) NMS
# video 1/1 (290/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1775.0ms) Inference, (0.2ms) NMS
# video 1/1 (291/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1908.7ms) Inference, (0.5ms) NMS
# video 1/1 (292/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1699.2ms) Inference, (0.3ms) NMS
# video 1/1 (293/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1692.2ms) Inference, (0.2ms) NMS
# video 1/1 (294/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1712.9ms) Inference, (0.3ms) NMS
# video 1/1 (295/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1791.1ms) Inference, (0.2ms) NMS
# video 1/1 (296/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1793.4ms) Inference, (0.2ms) NMS
# video 1/1 (297/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1702.2ms) Inference, (0.2ms) NMS
# video 1/1 (298/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1780.1ms) Inference, (0.3ms) NMS
# video 1/1 (299/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1794.4ms) Inference, (0.8ms) NMS
# video 1/1 (300/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1844.1ms) Inference, (0.2ms) NMS
# video 1/1 (301/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1871.0ms) Inference, (0.2ms) NMS
# video 1/1 (302/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1835.3ms) Inference, (0.2ms) NMS
# video 1/1 (303/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1775.8ms) Inference, (0.5ms) NMS
# video 1/1 (304/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1673.2ms) Inference, (0.4ms) NMS
# video 1/1 (305/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1749.5ms) Inference, (0.2ms) NMS
# video 1/1 (306/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1811.7ms) Inference, (0.4ms) NMS
# video 1/1 (307/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1758.0ms) Inference, (0.3ms) NMS
# video 1/1 (308/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1833.0ms) Inference, (0.2ms) NMS
# video 1/1 (309/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1791.8ms) Inference, (0.2ms) NMS
# video 1/1 (310/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1759.7ms) Inference, (0.4ms) NMS
# video 1/1 (311/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1938.7ms) Inference, (0.1ms) NMS
# video 1/1 (312/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1811.8ms) Inference, (0.2ms) NMS
# video 1/1 (313/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1962.6ms) Inference, (0.2ms) NMS
# video 1/1 (314/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1864.1ms) Inference, (0.6ms) NMS
# video 1/1 (315/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2146.2ms) Inference, (0.1ms) NMS
# video 1/1 (316/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1864.7ms) Inference, (0.2ms) NMS
# video 1/1 (317/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2140.1ms) Inference, (0.8ms) NMS
# video 1/1 (318/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2214.3ms) Inference, (0.3ms) NMS
# video 1/1 (319/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2115.6ms) Inference, (0.2ms) NMS
# video 1/1 (320/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2082.3ms) Inference, (0.3ms) NMS
# video 1/1 (321/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1893.2ms) Inference, (0.3ms) NMS
# video 1/1 (322/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1723.1ms) Inference, (0.2ms) NMS
# video 1/1 (323/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2296.7ms) Inference, (0.3ms) NMS
# video 1/1 (324/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1770.8ms) Inference, (0.3ms) NMS
# video 1/1 (325/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2099.7ms) Inference, (0.5ms) NMS
# video 1/1 (326/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1836.8ms) Inference, (0.6ms) NMS
# video 1/1 (327/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1997.6ms) Inference, (0.3ms) NMS
# video 1/1 (328/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1822.5ms) Inference, (0.8ms) NMS
# video 1/1 (329/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1774.9ms) Inference, (0.3ms) NMS
# ...
# 1 go_ahead, Done. (1893.0ms) Inference, (0.6ms) NMS
# video 1/1 (1676/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# 1 go_ahead, Done. (1792.1ms) Inference, (0.5ms) NMS
# video 1/1 (1677/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# 1 go_ahead, Done. (2124.5ms) Inference, (0.7ms) NMS
# video 1/1 (1678/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# 1 go_ahead, Done. (1849.7ms) Inference, (0.8ms) NMS
# video 1/1 (1679/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# 1 go_ahead, Done. (1911.9ms) Inference, (0.6ms) NMS
# video 1/1 (1680/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# 1 go_ahead, Done. (1880.0ms) Inference, (0.5ms) NMS
# video 1/1 (1681/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# 1 go_ahead, Done. (1843.8ms) Inference, (0.9ms) NMS
# video 1/1 (1682/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# 1 go_ahead, Done. (2479.3ms) Inference, (1.7ms) NMS
# video 1/1 (1683/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# 1 go_ahead, Done. (2247.9ms) Inference, (0.5ms) NMS
# video 1/1 (1684/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# 1 go_ahead, Done. (2132.0ms) Inference, (0.7ms) NMS
# video 1/1 (1685/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# 1 go_ahead, Done. (2525.4ms) Inference, (1.4ms) NMS
# video 1/1 (1686/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# 1 go_ahead, Done. (2137.4ms) Inference, (0.9ms) NMS
# video 1/1 (1687/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# 1 go_ahead, Done. (1744.4ms) Inference, (0.5ms) NMS
# video 1/1 (1688/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# 1 go_ahead, 1 right, Done. (2903.1ms) Inference, (0.8ms) NMS
# video 1/1 (1689/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# 1 go_ahead, 1 right, Done. (1749.2ms) Inference, (0.7ms) NMS
# video 1/1 (1690/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# 1 go_ahead, 1 right, Done. (1852.0ms) Inference, (0.5ms) NMS
# video 1/1 (1691/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# 1 go_ahead, 1 right, Done. (2068.5ms) Inference, (0.6ms) NMS
# video 1/1 (1692/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# 1 right, Done. (2085.4ms) Inference, (0.9ms) NMS
# video 1/1 (1693/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# 1 right, Done. (2602.0ms) Inference, (0.6ms) NMS
# video 1/1 (1694/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# 1 right, Done. (2184.5ms) Inference, (1.2ms) NMS
# video 1/1 (1695/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# 1 right, Done. (2051.0ms) Inference, (0.5ms) NMS
# video 1/1 (1696/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# 1 right, Done. (2513.9ms) Inference, (1.3ms) NMS
# video 1/1 (1697/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# 1 right, Done. (2694.9ms) Inference, (0.7ms) NMS
# video 1/1 (1698/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# 1 right, Done. (2832.2ms) Inference, (1.0ms) NMS
# video 1/1 (1699/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# 1 right, Done. (2320.1ms) Inference, (0.7ms) NMS
# video 1/1 (1700/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# 1 right, Done. (2263.0ms) Inference, (1.9ms) NMS
# video 1/1 (1701/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# 1 right, Done. (1990.1ms) Inference, (0.7ms) NMS
# video 1/1 (1702/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# 1 right, Done. (2123.3ms) Inference, (0.7ms) NMS
# video 1/1 (1703/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# 1 right, Done. (1974.7ms) Inference, (0.6ms) NMS
# video 1/1 (1704/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# 1 right, Done. (2305.1ms) Inference, (0.8ms) NMS
# video 1/1 (1705/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# 1 right, Done. (2545.6ms) Inference, (1.2ms) NMS
# video 1/1 (1706/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# 1 right, Done. (2178.9ms) Inference, (0.8ms) NMS
# video 1/1 (1707/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# 1 right, Done. (2160.1ms) Inference, (0.9ms) NMS
# video 1/1 (1708/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# 1 right, Done. (2178.5ms) Inference, (0.6ms) NMS
# video 1/1 (1709/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# 1 right, Done. (1913.8ms) Inference, (0.7ms) NMS
# video 1/1 (1710/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# 1 right, Done. (1934.7ms) Inference, (0.5ms) NMS
# video 1/1 (1711/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# 1 right, Done. (1789.6ms) Inference, (0.6ms) NMS
# video 1/1 (1712/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# 1 right, Done. (2737.1ms) Inference, (1.4ms) NMS
# video 1/1 (1713/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# 1 right, Done. (2007.4ms) Inference, (0.6ms) NMS
# video 1/1 (1714/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# 1 right, Done. (2137.6ms) Inference, (0.7ms) NMS
# video 1/1 (1715/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# 1 right, Done. (2079.2ms) Inference, (1.0ms) NMS
# video 1/1 (1716/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# 1 right, Done. (2201.6ms) Inference, (0.6ms) NMS
# video 1/1 (1717/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# 1 right, Done. (2266.4ms) Inference, (0.8ms) NMS
# video 1/1 (1718/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# 1 right, Done. (2225.4ms) Inference, (0.5ms) NMS
# video 1/1 (1719/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# 1 right, Done. (2406.3ms) Inference, (0.9ms) NMS
# video 1/1 (1720/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# 1 right, Done. (2437.0ms) Inference, (0.8ms) NMS
# video 1/1 (1721/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# 1 right, Done. (2279.1ms) Inference, (0.6ms) NMS
# video 1/1 (1722/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# 1 right, Done. (1956.9ms) Inference, (0.5ms) NMS
# video 1/1 (1723/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# 1 right, Done. (2310.3ms) Inference, (0.8ms) NMS
# video 1/1 (1724/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# 1 right, Done. (2174.0ms) Inference, (0.6ms) NMS
# video 1/1 (1725/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# 1 right, Done. (1930.4ms) Inference, (1.0ms) NMS
# video 1/1 (1726/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# 1 right, Done. (1842.5ms) Inference, (0.9ms) NMS
# video 1/1 (1727/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# 1 right, Done. (1710.6ms) Inference, (0.6ms) NMS
# video 1/1 (1728/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# 1 right, Done. (2293.9ms) Inference, (1.0ms) NMS
# video 1/1 (1729/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# 1 right, Done. (2037.2ms) Inference, (0.8ms) NMS
# video 1/1 (1730/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# 1 right, Done. (1817.3ms) Inference, (1.1ms) NMS
# video 1/1 (1731/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# 1 right, Done. (1651.0ms) Inference, (0.5ms) NMS
# video 1/1 (1732/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# 1 right, Done. (1645.2ms) Inference, (0.5ms) NMS
# video 1/1 (1733/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# 1 right, Done. (1882.9ms) Inference, (0.6ms) NMS
# video 1/1 (1734/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2047.8ms) Inference, (0.7ms) NMS
# video 1/1 (1735/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1804.6ms) Inference, (0.4ms) NMS
# video 1/1 (1736/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1710.7ms) Inference, (0.5ms) NMS
# video 1/1 (1737/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1754.9ms) Inference, (0.1ms) NMS
# video 1/1 (1738/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1788.6ms) Inference, (2.3ms) NMS
# video 1/1 (1739/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1757.0ms) Inference, (0.3ms) NMS
# video 1/1 (1740/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2718.4ms) Inference, (0.5ms) NMS
# video 1/1 (1741/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2440.3ms) Inference, (0.1ms) NMS
# video 1/1 (1742/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1998.2ms) Inference, (0.2ms) NMS
# video 1/1 (1743/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1794.8ms) Inference, (0.4ms) NMS
# video 1/1 (1744/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1713.4ms) Inference, (0.1ms) NMS
# video 1/1 (1745/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (1743.6ms) Inference, (0.5ms) NMS
# video 1/1 (1746/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# Done. (2444.7ms) Inference, (0.2ms) NMS
# video 1/1 (1747/6401) /Users/bmd1905/Desktop/AIO_final_project/yolov7/../video/source.mp4: (1080, 1920, 3)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 3
#       1 # opt.source = '../train_data/train/images/img_126.jpg'
#       2 opt.source = '../video/source.mp4'
# ----> 3 img_rgba = detect()
#
# Cell In[13], line 81, in detect(save_img)
#      78 yolo_output = yolo(img, augment=opt.augment)[0]
#      80 # Unet
# ---> 81 img_mask = unet(img).cpu()
#      82 img_mask = F.interpolate(img_mask, (np_img0s.shape[0], np_img0s.shape[1]), mode='bilinear')
#      83 if unet.n_classes > 1:
#
# File ~/miniforge3/envs/yolov7_env/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Desktop/AIO_final_project/yolov7/unet/unet_model.py:26, in UNet.forward(self, x)
#      25 def forward(self, x):
# ---> 26     x1 = self.inc(x)
#      27     x2 = self.down1(x1)
#      28     x3 = self.down2(x2)
#
# File ~/miniforge3/envs/yolov7_env/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Desktop/AIO_final_project/yolov7/unet/unet_parts.py:25, in DoubleConv.forward(self, x)
#      24 def forward(self, x):
# ---> 25     return self.double_conv(x)
#
# File ~/miniforge3/envs/yolov7_env/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniforge3/envs/yolov7_env/lib/python3.10/site-packages/torch/nn/modules/container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File ~/miniforge3/envs/yolov7_env/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniforge3/envs/yolov7_env/lib/python3.10/site-packages/torch/nn/modules/conv.py:463, in Conv2d.forward(self, input)
#     462 def forward(self, input: Tensor) -> Tensor:
# --> 463     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/miniforge3/envs/yolov7_env/lib/python3.10/site-packages/torch/nn/modules/conv.py:459, in Conv2d._conv_forward(self, input, weight, bias)
#     455 if self.padding_mode != 'zeros':
#     456     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     457                     weight, bias, self.stride,
#     458                     _pair(0), self.dilation, self.groups)
# --> 459 return F.conv2d(input, weight, bias, self.stride,
#     460                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:

# %%
img_rgba.shape

# %% [markdown]
# # Roboflow

# %%
# from roboflow import Roboflow

# rf = Roboflow(api_key="2zhs3MwGLPb82RpOi7yl")
# project = rf.workspace().project("lane-detection-ab1uw")
# model = project.version(1).model

# %%
# save an image annotated with your predictions
model.predict("test/images/img_176.jpg").save("prediction.jpg")

# %%
import cv2
import os
import numpy as np

# Load pre-trained segmentation model
# Replace this with the actual code to load your segmentation model
def load_model():
    # Your code here
    return model

# Function to predict segmentation mask for an input frame
def predict_segmentation(frame, model):
    # Pre-process the frame (if needed)
    # Replace this with your own pre-processing logic
    
    # Perform segmentation prediction using the model
    segmentation_mask = model.predict(frame)
    
    # Post-process the segmentation mask (if needed)
    # Replace this with your own post-processing logic
    
    return segmentation_mask

# Load video file
video_file = "../video/source.mp4"  # Replace with your video file path
cap = cv2.VideoCapture(video_file)

# Get frames per second (fps) and frame size of input video
fps = int(cap.get(cv2.CAP_PROP_FPS))
frame_size = (int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)), int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT)))

# Create a folder to save the temporary image files
output_folder = "output_folder"  # Replace with the folder path where you want to save the temporary image files
os.makedirs(output_folder, exist_ok=True)

# Define the codec for the output video file
fourcc = cv2.VideoWriter_fourcc(*'XVID')  # Change codec as per your requirements

# Create video writer object to save the output video
output_file = "file.avi"  # Replace with your output video file path
out = cv2.VideoWriter(output_file, fourcc, fps, frame_size)

# Loop through each frame of the video
while True:
    ret, frame = cap.read()
    if not ret:
        break
    
    # Save the frame as a temporary image file
    temp_image_file = os.path.join(output_folder, f"frame_{cap.get(cv2.CAP_PROP_POS_FRAMES)}.jpg")
    cv2.imwrite(temp_image_file, frame)
    
    
    # Pass the image through the segmentation model
    segmentation_mask = predict_segmentation(temp_image_file, model)
    # print(type(segmentation_mask))
    # break

    # Convert PredictionGroup to numpy array
    segmentation_mask = np.asarray(segmentation_mask.to_pixels())


    # Post-process the segmentation mask (if needed)
    # Replace this with your own post-processing logic
    
    # Write the frame with segmentation mask to the output video
    out.write(segmentation_mask)
    
    # Delete the temporary image file
    os.remove(temp_image_file)

# Release video capture and writer objects
cap.release()
out.release()

# Remove the temporary output folder
os.rmdir(output_folder)

# %%
segmentation_mask.pixels
